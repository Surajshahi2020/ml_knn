# %%
import pandas as pd
import warnings; warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
#Reading the csv file 
movie_data = pd.read_csv('Knn.csv')
movie_data
# Out:
#    Rating  Duration   Genre
# 0     8.0       160  Action
# 1     6.2       170  Action
# 2     7.2       168  Comedy
# 3     8.2       155  Comedy

# %%
#Data Analysis
movie_data['Genre'].unique()
movie_data['Genre'] = movie_data['Genre'].replace(['Action', 'Comedy'],[1,2])
movie_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Rating    4 non-null      float64
#  1   Duration  4 non-null      int64
#  2   Genre     4 non-null      int64
# dtypes: float64(1), int64(2)
# memory usage: 228.0 bytes

# %%
input_data = movie_data.drop(columns='Genre')
output_data = movie_data['Genre']
x_train,x_test,y_train,y_test = train_test_split(input_data,output_data,test_size=0.2,random_state=42)

# %%
#Model creation
model = KNeighborsClassifier(n_neighbors=3)

# %%
#Train model
model.fit(input_data,output_data)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
#Predict model
predict = model.predict(x_test)
predict
# Out:
# array([1], dtype=int64)

# %%
#Model evaluation
accuracy = accuracy_score(y_test, predict)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 1.0

# %%
#Prediction on our own test data for vscode
input_data_model = pd.DataFrame([[7.4,114]],columns=['Rating','Duration'])
input_data_model
model.predict(input_data_model)
# Out:
# array([2], dtype=int64)
